# %%
##Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
##Data Import
##Download dataset from Kaggle
import opendatasets as od
od.download("https://www.kaggle.com/datasets/marcopale/housing")
# Out:
# Skipping, found downloaded files in "./housing" (use force=True to force download)

# %%
##Training Data Overview
##Read the training data from the csv and show the columns
pd.set_option('max_columns', None)
pd.set_option('display.max_rows', None)
df_train = pd.read_csv('housing/train.csv')
df_train.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    534  531363010           20        RL          80.0      9605   Pave
# 1    803  906203120           20        RL          90.0     14684   Pave
# 2    956  916176030           20        RL           NaN     14375   Pave
# 3    460  528180130          120        RL          48.0      6472   Pave
# 4    487  528290030           80        RL          61.0      9734   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       Reg          Lvl    AllPub     Corner        Gtl      SawyerW
# 1   NaN       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2   NaN       IR1          Lvl    NoSeWa    CulDSac        Gtl       Timber
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
# ...

# %%
df_train.count(axis=0)
# Out:
# Order              2197
# PID                2197
# MS SubClass        2197
# MS Zoning          2197
# Lot Frontage       1835
# Lot Area           2197
# Street             2197
# Alley               143
# Lot Shape          2197
# Land Contour       2197
# Utilities          2197
# Lot Config         2197
# Land Slope         2197
# Neighborhood       2197
# Condition 1        2197
# Condition 2        2197
# Bldg Type          2197
# House Style        2197
# Overall Qual       2197
# Overall Cond       2197
# Year Built         2197
# Year Remod/Add     2197
# Roof Style         2197
# Roof Matl          2197
# Exterior 1st       2197
# Exterior 2nd       2197
# Mas Vnr Type       2175
# Mas Vnr Area       2175
# Exter Qual         2197
# Exter Cond         2197
# Foundation         2197
# Bsmt Qual          2130
# Bsmt Cond          2130
# Bsmt Exposure      2128
# BsmtFin Type 1     2130
# BsmtFin SF 1       2196
# BsmtFin Type 2     2129
# BsmtFin SF 2       2196
# ...

# %%
##Test Data Import
##Read the test data from the csv and show the columns
df_test = pd.read_csv('housing/test.csv')
df_test.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   2127  907135180           20        RL          60.0      8070   Pave
# 1    193  903206120           75        RL           NaN      7793   Pave
# 2   2407  528181040          120        RL          40.0      6792   Pave
# 3     46  528175010          120        RL          44.0      6371   Pave
# 4   2478  531379030           60        RL          70.0      8304   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       Reg          Lvl    AllPub     Inside        Gtl      CollgCr
# 1   NaN       IR1          Bnk    AllPub     Corner        Gtl      BrkSide
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      NridgHt
# 3   NaN       IR1          Lvl    AllPub     Inside        Gtl      NridgHt
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
df_test.count(axis=0)
# Out:
# Order              733
# PID                733
# MS SubClass        733
# MS Zoning          733
# Lot Frontage       605
# Lot Area           733
# Street             733
# Alley               55
# Lot Shape          733
# Land Contour       733
# Utilities          733
# Lot Config         733
# Land Slope         733
# Neighborhood       733
# Condition 1        733
# Condition 2        733
# Bldg Type          733
# House Style        733
# Overall Qual       733
# Overall Cond       733
# Year Built         733
# Year Remod/Add     733
# Roof Style         733
# Roof Matl          733
# Exterior 1st       733
# Exterior 2nd       733
# Mas Vnr Type       732
# Mas Vnr Area       732
# Exter Qual         733
# Exter Cond         733
# Foundation         733
# Bsmt Qual          720
# Bsmt Cond          720
# Bsmt Exposure      719
# BsmtFin Type 1     720
# BsmtFin SF 1       733
# BsmtFin Type 2     720
# BsmtFin SF 2       733
# Bsmt Unf SF        733
# Total Bsmt SF      733
# ...

# %%
#Data Overview
print(df_train.shape)
print(df_train.info())
# Out:
# (2197, 82)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197 entries, 0 to 2196
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2197 non-null   int64
#  1   PID              2197 non-null   int64
#  2   MS SubClass      2197 non-null   int64
#  3   MS Zoning        2197 non-null   object
#  4   Lot Frontage     1835 non-null   float64
#  5   Lot Area         2197 non-null   int64
#  6   Street           2197 non-null   object
#  7   Alley            143 non-null    object
#  8   Lot Shape        2197 non-null   object
#  9   Land Contour     2197 non-null   object
#  10  Utilities        2197 non-null   object
#  11  Lot Config       2197 non-null   object
#  12  Land Slope       2197 non-null   object
#  13  Neighborhood     2197 non-null   object
#  14  Condition 1      2197 non-null   object
#  15  Condition 2      2197 non-null   object
# ...

# %%
#Data CLeaning
#Check missing values or null values and return the sum
df_train.isnull().sum()
# Out:
# Order                 0
# PID                   0
# MS SubClass           0
# MS Zoning             0
# Lot Frontage        362
# Lot Area              0
# Street                0
# Alley              2054
# Lot Shape             0
# Land Contour          0
# Utilities             0
# Lot Config            0
# Land Slope            0
# Neighborhood          0
# Condition 1           0
# Condition 2           0
# Bldg Type             0
# House Style           0
# Overall Qual          0
# Overall Cond          0
# Year Built            0
# Year Remod/Add        0
# Roof Style            0
# Roof Matl             0
# Exterior 1st          0
# Exterior 2nd          0
# Mas Vnr Type         22
# Mas Vnr Area         22
# Exter Qual            0
# Exter Cond            0
# Foundation            0
# Bsmt Qual            67
# Bsmt Cond            67
# Bsmt Exposure        69
# BsmtFin Type 1       67
# BsmtFin SF 1          1
# BsmtFin Type 2       68
# BsmtFin SF 2          1
# ...

# %%
#1. Drop columns with more than 15% of the data

drop_columns = ['Pool QC','Misc Feature', 'Alley','Fence','Fireplace Qu','Lot Frontage']
df.drop(columns=drop_columns, inplace=True)

df.head()

# %%
# if column is numerical
def numerical(column):
    a = df_train[column].mean()
    b = df_train[column].isnull().sum()
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.suptitle('Relationship between ' + column + ' and Sale Price')
    fig.set_figheight(8)
    fig.set_figwidth(14)
    ax1.scatter(x=df_train[column], y=df_train['SalePrice'])
    ax2.hist(x=df_train[column])
    ax1.set(xlabel=column,ylabel="Sale Price")
    ax2.set(xlabel=column,ylabel="Number of Instances")
    print(column + ' Mean equals', a)
    print(column + ' Amount of nulls equals', b)
ahd1 = df_train[['Total Bsmt SF', '1st Flr SF','2nd Flr SF', 'Wood Deck SF','Lot Area','Gr Liv Area','Garage Area','Pool Area','Overall Qual','Overall Cond','SalePrice']].dropna()
for i in ahd1.columns[:-1]:
    numerical(i)
# Out:
# Total Bsmt SF Mean equals 1062.0209471766848
# Total Bsmt SF Amount of nulls equals 1
# 1st Flr SF Mean equals 1171.7446517979063
# 1st Flr SF Amount of nulls equals 0
# 2nd Flr SF Mean equals 331.9321802457897
# 2nd Flr SF Amount of nulls equals 0
# Wood Deck SF Mean equals 92.43695949021392
# Wood Deck SF Amount of nulls equals 0
# Lot Area Mean equals 10268.070095584888
# Lot Area Amount of nulls equals 0
# Gr Liv Area Mean equals 1507.873463814292
# Gr Liv Area Amount of nulls equals 0
# Garage Area Mean equals 476.7158469945355
# Garage Area Amount of nulls equals 1
# Pool Area Mean equals 2.7897132453345472
# Pool Area Amount of nulls equals 0
# Overall Qual Mean equals 6.1165225307237145
# Overall Qual Amount of nulls equals 0
# Overall Cond Mean equals 5.552571688666363
# Overall Cond Amount of nulls equals 0

# %%
df_train['SalePrice'].plot.hist(bins=20, edgecolor="black")
plt.xlabel("House price in $")
_ = plt.title("Distribution of the house price \nin Ames")

# %%
fig, ax = plt.subplots(figsize=(20, 10))
_ = df_train['SalePrice'].hist(bins=20,
                                 ax=ax)
