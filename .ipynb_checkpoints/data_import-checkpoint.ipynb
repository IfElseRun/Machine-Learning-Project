# %%
from Libraries import *

# %%
## Data Import
## To download dataset from Kaggle I will use opendatasets library
## In order to do so I have created API Token using my Kaggle account that I will need to download resource
od.download("https://www.kaggle.com/datasets/marcopale/housing")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: adnalakisic
# Your Kaggle Key: ········
# ...
# 100%|██████████| 397k/397k [00:00<00:00, 1.65MB/s]

# %%
## I will review number of columns and rows for train and test dataset
## Seems it is 70:30 Pareto ratio and we can already use split data in these 2 files
train_dataset = pd.read_csv('housing/train.csv')
train_dataset.shape
# Out:
# (2197, 82)

# %%
test_dataset = pd.read_csv('housing/test.csv')
test_dataset.shape
# Out:
# (733, 81)

# %%
## Let's review columns in the train dataset to better understand dataset
##Quantitative Data
quantitative_ds = train_dataset.select_dtypes(include=['float64', 'int64'])
quantitative_ds = quantitative_ds.fillna(num_df.mean())
qd
# Out:
#       Order        PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# 0       534  531363010           20     80.000000      9605             7
# 1       803  906203120           20     90.000000     14684             7
# 2       956  916176030           20     69.549319     14375             6
# 3       460  528180130          120     48.000000      6472             9
# 4       487  528290030           80     61.000000      9734             7
# ...     ...        ...          ...           ...       ...           ...
# 2192   2764  906420020           60     80.000000     10041             8
# 2193    906  909129090           50     70.000000      6300             5
# 2194   1097  528292060           60     41.000000     12460             7
# 2195    236  905426060           30     85.000000     10625             5
# 2196   1062  528142020           60     74.000000      8899             8
#
#       Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  ...  \
# ...

# %%
## Qualitative Data

qualitative_ds = train_dataset.select_dtypes(include=['object'])
qualitative_ds = qualitative_ds.fillna(obj_df.mode().iloc[0])
qualitative_ds
# Out:
#      MS Zoning Street Alley Lot Shape Land Contour Utilities Lot Config  \
# 0           RL   Pave  Grvl       Reg          Lvl    AllPub     Corner
# 1           RL   Pave  Grvl       IR1          Lvl    AllPub    CulDSac
# 2           RL   Pave  Grvl       IR1          Lvl    NoSeWa    CulDSac
# 3           RL   Pave  Grvl       Reg          Lvl    AllPub     Inside
# 4           RL   Pave  Grvl       IR1          Lvl    AllPub     Inside
# ...        ...    ...   ...       ...          ...       ...        ...
# 2192        RL   Pave  Grvl       IR1          Lvl    AllPub     Inside
# 2193        RH   Pave  Pave       Reg          Lvl    AllPub     Corner
# 2194        RL   Pave  Grvl       IR1          Lvl    AllPub        FR2
# 2195        RL   Pave  Grvl       Reg          Lvl    AllPub     Corner
# 2196        RL   Pave  Grvl       Reg          Lvl    AllPub     Inside
#
#      Land Slope Neighborhood Condition 1  ... Garage Type Garage Finish  \
# ...

# %%
##Quantitative Data Columns List (Numerical)
list(quantitative_ds)
# Out:
# ['Order',
#  'PID',
#  'MS SubClass',
#  'Lot Frontage',
#  'Lot Area',
#  'Overall Qual',
#  'Overall Cond',
#  'Year Built',
#  'Year Remod/Add',
#  'Mas Vnr Area',
#  'BsmtFin SF 1',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  '1st Flr SF',
#  '2nd Flr SF',
#  'Low Qual Fin SF',
#  'Gr Liv Area',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Full Bath',
#  'Half Bath',
#  'Bedroom AbvGr',
#  'Kitchen AbvGr',
#  'TotRms AbvGrd',
#  'Fireplaces',
#  'Garage Yr Blt',
#  'Garage Cars',
#  'Garage Area',
#  'Wood Deck SF',
#  'Open Porch SF',
#  'Enclosed Porch',
#  '3Ssn Porch',
#  'Screen Porch',
#  'Pool Area',
#  'Misc Val',
#  'Mo Sold',
#  'Yr Sold',
#  'SalePrice']

# %%
##Qualitative Data Columns List (Categorical)
list(qualitative_ds)
# Out:
# ['MS Zoning',
#  'Street',
#  'Alley',
#  'Lot Shape',
#  'Land Contour',
#  'Utilities',
#  'Lot Config',
#  'Land Slope',
#  'Neighborhood',
#  'Condition 1',
#  'Condition 2',
#  'Bldg Type',
#  'House Style',
#  'Roof Style',
#  'Roof Matl',
#  'Exterior 1st',
#  'Exterior 2nd',
#  'Mas Vnr Type',
#  'Exter Qual',
#  'Exter Cond',
#  'Foundation',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin Type 2',
#  'Heating',
#  'Heating QC',
#  'Central Air',
#  'Electrical',
#  'Kitchen Qual',
#  'Functional',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Finish',
#  'Garage Qual',
#  'Garage Cond',
#  'Paved Drive',
#  'Pool QC',
#  'Fence',
#  'Misc Feature',
#  'Sale Type',
#  'Sale Condition']

# %%
list(train_dataset["Neighborhood"].unique())
# Out:
# ['SawyerW',
#  'Timber',
#  'NridgHt',
#  'Gilbert',
#  'NAmes',
#  'Mitchel',
#  'NWAmes',
#  'MeadowV',
#  'CollgCr',
#  'OldTown',
#  'BrkSide',
#  'Sawyer',
#  'StoneBr',
#  'NoRidge',
#  'Edwards',
#  'ClearCr',
#  'Somerst',
#  'IDOTRR',
#  'Crawfor',
#  'SWISU',
#  'Blmngtn',
#  'Veenker',
#  'NPkVill',
#  'Landmrk',
#  'BrDale',
#  'Greens',
#  'Blueste',
#  'GrnHill']
